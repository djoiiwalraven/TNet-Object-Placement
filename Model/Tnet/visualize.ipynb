# %%
import torch
import graphviz
import torchvision
from torchview import draw_graph

from Tnet import Tnet


# when running on VSCode run the below command
# svg format on vscode does not give desired result
graphviz.set_jupyter_format('png')
# Out:
# 'svg'

# %%
model = Tnet(in_channels=3,out_channels=3)

# %%
print(model)
# Out:
# Tnet(
#   (downs): ModuleList(
#     (0): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (1): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (2): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (3): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (ups): ModuleList(
#     (0): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#     (1): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (2): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (3): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (4): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (5): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (6): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (7): ConvBlock(
#       (conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (attention_blocks): ModuleList(
#     (0): AttentionBlock(
#       (W_g): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (W_x): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (psi): Sequential(
#         (0): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): AttentionBlock(
#       (W_g): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (W_x): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (psi): Sequential(
#         (0): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (2): AttentionBlock(
#       (W_g): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (W_x): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (psi): Sequential(
#         (0): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (3): AttentionBlock(
#       (W_g): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (W_x): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (psi): Sequential(
#         (0): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): ConvBlock(
#     (conv): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (final_conv): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
model_graph = draw_graph(model,input_size=(1,3,32,32))
model_graph.visual_graph
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/torchview.py:256, in forward_prop(model, x, device, model_graph, mode, **kwargs)
#     255 if isinstance(x, (list, tuple)):
# --> 256     _ = model.to(device)(*x, **kwargs)
#     257 elif isinstance(x, Mapping):
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:146, in module_forward_wrapper.<locals>._module_forward_wrapper(mod, *args, **kwargs)
#     144 # TODO: check if output contains RecorderTensor
#     145 # this seems not to be necessary so far
# --> 146 out = _orig_module_forward(mod, *args, **kwargs)
#     148 model_graph.context_tracker['current_depth'] = cur_depth
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/Projects/Pix2Plan/Model/Tnet/Tnet.py:115, in Tnet.forward(self, x)
#     114 for down in self.downs:
# --> 115     x = down(x)
#     116     skip_connections.append(x)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:146, in module_forward_wrapper.<locals>._module_forward_wrapper(mod, *args, **kwargs)
#     144 # TODO: check if output contains RecorderTensor
#     145 # this seems not to be necessary so far
# --> 146 out = _orig_module_forward(mod, *args, **kwargs)
#     148 model_graph.context_tracker['current_depth'] = cur_depth
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/Projects/Pix2Plan/Model/Tnet/Tnet.py:25, in ConvBlock.forward(self, x)
#      24 def forward(self, x):
# ---> 25     return self.conv(x)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:146, in module_forward_wrapper.<locals>._module_forward_wrapper(mod, *args, **kwargs)
#     144 # TODO: check if output contains RecorderTensor
#     145 # this seems not to be necessary so far
# --> 146 out = _orig_module_forward(mod, *args, **kwargs)
#     148 model_graph.context_tracker['current_depth'] = cur_depth
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:146, in module_forward_wrapper.<locals>._module_forward_wrapper(mod, *args, **kwargs)
#     144 # TODO: check if output contains RecorderTensor
#     145 # this seems not to be necessary so far
# --> 146 out = _orig_module_forward(mod, *args, **kwargs)
#     148 model_graph.context_tracker['current_depth'] = cur_depth
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:241, in RecorderTensor.__torch_function__(cls, func, types, args, kwargs)
#     238 else:
#     239     # use original torch_function; otherwise,
#     240     # it leads to infinite recursive call of torch_function
# --> 241     out = super().__torch_function__(func, types, args, kwargs)
#     243 # if no RecorderTensor is found in input or output
#     244 # dont create any node, give the result only
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/_tensor.py:1512, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1511 with _C.DisableTorchFunctionSubclass():
# -> 1512     ret = func(*args, **kwargs)
#    1513     if func in get_default_nowrap_functions():
#
# RuntimeError: Given groups=1, weight of size [64, 1, 3, 3], expected input[1, 3, 32, 32] to have 1 channels, but got 3 channels instead
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model_graph = draw_graph(model,input_size=(1,3,32,32))
#       2 model_graph.visual_graph
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/torchview.py:220, in draw_graph(model, input_data, input_size, graph_name, depth, device, dtypes, mode, strict, expand_nested, graph_dir, hide_module_functions, hide_inner_tensors, roll, show_shapes, save_graph, filename, directory, **kwargs)
#     211 input_recorder_tensor, kwargs_record_tensor, input_nodes = process_input(
#     212     input_data, input_size, kwargs, device, dtypes
#     213 )
#     215 model_graph = ComputationGraph(
#     216     visual_graph, input_nodes, show_shapes, expand_nested,
#     217     hide_inner_tensors, hide_module_functions, roll, depth
#     218 )
# --> 220 forward_prop(
#     221     model, input_recorder_tensor, device, model_graph,
#     222     model_mode, **kwargs_record_tensor
#     223 )
#     225 model_graph.fill_visual_graph()
#     227 if save_graph:
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/torchview.py:264, in forward_prop(model, x, device, model_graph, mode, **kwargs)
#     262                 raise ValueError("Unknown input type")
#     263 except Exception as e:
# --> 264     raise RuntimeError(
#     265         "Failed to run torchgraph see error message"
#     266     ) from e
#     267 finally:
#     268     model.train(saved_model_mode)
#
# RuntimeError: Failed to run torchgraph see error message

# %%
model_graph1 = draw_graph(Tnet(), input_size=(1,3,32,32))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/torchview.py:256, in forward_prop(model, x, device, model_graph, mode, **kwargs)
#     255 if isinstance(x, (list, tuple)):
# --> 256     _ = model.to(device)(*x, **kwargs)
#     257 elif isinstance(x, Mapping):
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:146, in module_forward_wrapper.<locals>._module_forward_wrapper(mod, *args, **kwargs)
#     144 # TODO: check if output contains RecorderTensor
#     145 # this seems not to be necessary so far
# --> 146 out = _orig_module_forward(mod, *args, **kwargs)
#     148 model_graph.context_tracker['current_depth'] = cur_depth
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/Projects/Pix2Plan/Model/Tnet/Tnet.py:115, in Tnet.forward(self, x)
#     114 for down in self.downs:
# --> 115     x = down(x)
#     116     skip_connections.append(x)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:146, in module_forward_wrapper.<locals>._module_forward_wrapper(mod, *args, **kwargs)
#     144 # TODO: check if output contains RecorderTensor
#     145 # this seems not to be necessary so far
# --> 146 out = _orig_module_forward(mod, *args, **kwargs)
#     148 model_graph.context_tracker['current_depth'] = cur_depth
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/Projects/Pix2Plan/Model/Tnet/Tnet.py:25, in ConvBlock.forward(self, x)
#      24 def forward(self, x):
# ---> 25     return self.conv(x)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:146, in module_forward_wrapper.<locals>._module_forward_wrapper(mod, *args, **kwargs)
#     144 # TODO: check if output contains RecorderTensor
#     145 # this seems not to be necessary so far
# --> 146 out = _orig_module_forward(mod, *args, **kwargs)
#     148 model_graph.context_tracker['current_depth'] = cur_depth
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:146, in module_forward_wrapper.<locals>._module_forward_wrapper(mod, *args, **kwargs)
#     144 # TODO: check if output contains RecorderTensor
#     145 # this seems not to be necessary so far
# --> 146 out = _orig_module_forward(mod, *args, **kwargs)
#     148 model_graph.context_tracker['current_depth'] = cur_depth
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/recorder_tensor.py:241, in RecorderTensor.__torch_function__(cls, func, types, args, kwargs)
#     238 else:
#     239     # use original torch_function; otherwise,
#     240     # it leads to infinite recursive call of torch_function
# --> 241     out = super().__torch_function__(func, types, args, kwargs)
#     243 # if no RecorderTensor is found in input or output
#     244 # dont create any node, give the result only
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torch/_tensor.py:1512, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1511 with _C.DisableTorchFunctionSubclass():
# -> 1512     ret = func(*args, **kwargs)
#    1513     if func in get_default_nowrap_functions():
#
# RuntimeError: Given groups=1, weight of size [64, 1, 3, 3], expected input[1, 3, 32, 32] to have 1 channels, but got 3 channels instead
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model_graph1 = draw_graph(Tnet(), input_size=(1,3,32,32))
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/torchview.py:220, in draw_graph(model, input_data, input_size, graph_name, depth, device, dtypes, mode, strict, expand_nested, graph_dir, hide_module_functions, hide_inner_tensors, roll, show_shapes, save_graph, filename, directory, **kwargs)
#     211 input_recorder_tensor, kwargs_record_tensor, input_nodes = process_input(
#     212     input_data, input_size, kwargs, device, dtypes
#     213 )
#     215 model_graph = ComputationGraph(
#     216     visual_graph, input_nodes, show_shapes, expand_nested,
#     217     hide_inner_tensors, hide_module_functions, roll, depth
#     218 )
# --> 220 forward_prop(
#     221     model, input_recorder_tensor, device, model_graph,
#     222     model_mode, **kwargs_record_tensor
#     223 )
#     225 model_graph.fill_visual_graph()
#     227 if save_graph:
#
# File ~/miniconda3/envs/dlview/lib/python3.12/site-packages/torchview/torchview.py:264, in forward_prop(model, x, device, model_graph, mode, **kwargs)
#     262                 raise ValueError("Unknown input type")
#     263 except Exception as e:
# --> 264     raise RuntimeError(
#     265         "Failed to run torchgraph see error message"
#     266     ) from e
#     267 finally:
#     268     model.train(saved_model_mode)
#
# RuntimeError: Failed to run torchgraph see error message

# %%
model_graph1.visual_graph
